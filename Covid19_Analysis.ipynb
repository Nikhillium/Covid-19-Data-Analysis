# %% [markdown]
# ## Title: Covid - 19 Data Analysis Project using Python

# %% [markdown]
# # Importing essential libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Import the dataset using Pandas

# %%
df = pd.read_csv("covid_Data.csv", sep =",")

# %% [markdown]
# # Display first 5 rows

# %%
df.head()
# Out:
#    Unnamed: 0 continent     location        date  total_cases  total_deaths  \
# 0           0      Asia  Afghanistan  2019-12-31          0.0           0.0
# 1           1      Asia  Afghanistan  2020-01-01          0.0           0.0
# 2           2      Asia  Afghanistan  2020-02-01          0.0           0.0
# 3           3      Asia  Afghanistan  2020-03-01          0.0           0.0
# 4           4      Asia  Afghanistan  2020-04-01          0.0           0.0
#
#    gdp_per_capita  human_development_index  month
# 0        1803.987                    0.498     12
# 1        1803.987                    0.498      1
# 2        1803.987                    0.498      2
# 3        1803.987                    0.498      3
# 4        1803.987                    0.498      4

# %% [markdown]
# # Display last 5 rows

# %%
df.tail()
# Out:
#        Unnamed: 0 continent       location        date  total_cases  \
# 57389       57389         0  International  2020-11-13        696.0
# 57390       57390         0  International  2020-11-14        696.0
# 57391       57391         0  International  2020-11-15        696.0
# 57392       57392         0  International  2020-11-16        696.0
# 57393       57393         0  International  2020-11-17        696.0
#
#        total_deaths  gdp_per_capita  human_development_index  month
# 57389           7.0             0.0                      0.0     11
# 57390           7.0             0.0                      0.0     11
# 57391           7.0             0.0                      0.0     11
# 57392           7.0             0.0                      0.0     11
# 57393           7.0             0.0                      0.0     11

# %% [markdown]
# # Display no.of rows & columns in the dataset

# %%
df.shape
# Out:
# (57394, 9)

# %% [markdown]
# # Display data types of columns

# %%
df.dtypes
# Out:
# Unnamed: 0                   int64
# continent                   object
# location                    object
# date                        object
# total_cases                float64
# total_deaths               float64
# gdp_per_capita             float64
# human_development_index    float64
# month                        int64
# dtype: object

# %% [markdown]
# # Information of the data in dataframe

# %%
df.info
# Out:
# <bound method DataFrame.info of        Unnamed: 0 continent       location        date  total_cases  \
# 0               0      Asia    Afghanistan  2019-12-31          0.0
# 1               1      Asia    Afghanistan  2020-01-01          0.0
# 2               2      Asia    Afghanistan  2020-02-01          0.0
# 3               3      Asia    Afghanistan  2020-03-01          0.0
# 4               4      Asia    Afghanistan  2020-04-01          0.0
# ...           ...       ...            ...         ...          ...
# 57389       57389         0  International  2020-11-13        696.0
# 57390       57390         0  International  2020-11-14        696.0
# 57391       57391         0  International  2020-11-15        696.0
# 57392       57392         0  International  2020-11-16        696.0
# 57393       57393         0  International  2020-11-17        696.0
#
#        total_deaths  gdp_per_capita  human_development_index  month
# ...

# %% [markdown]
# # Describe of data in dataframe

# %%
pd.set_option('display.max_columns', None)
df.describe(include="all").round(2)
# Out:
#         Unnamed: 0 continent     location        date  total_cases  \
# count     57394.00     57394        57394       57394     57394.00
# unique         NaN         7          216         323          NaN
# top            NaN    Europe  Afghanistan  2020-10-31          NaN
# freq           NaN     14828          323         215          NaN
# mean      28696.50       NaN          NaN         NaN    157167.14
# std       16568.37       NaN          NaN         NaN   1639040.66
# min           0.00       NaN          NaN         NaN         0.00
# 25%       14348.25       NaN          NaN         NaN        89.00
# 50%       28696.50       NaN          NaN         NaN      1545.00
# 75%       43044.75       NaN          NaN         NaN     17974.25
# max       57393.00       NaN          NaN         NaN  55154651.00
#
#         total_deaths  gdp_per_capita  human_development_index     month
# count       57394.00        57394.00                 57394.00  57394.00
# ...

# %% [markdown]
# # Find count of unique values in location column

# %%
df['location'].nunique()
# Out:
# 216

# %% [markdown]
# # Find which continent has maximum frequency using values counts.

# %%
df['continent'].value_counts()
# Out:
# continent
# Europe           14828
# Africa           13637
# Asia             13528
# North America     9116
# South America     3404
# Oceania           2235
# 0                  646
# Name: count, dtype: int64

# %% [markdown]
# # Calculating maximum, mean & minimum value in 'total_cases'

# %%
df['total_cases'].max()
# Out:
# 55154651.0

# %%
df['total_cases'].mean()
# Out:
# np.float64(157167.1421402934)

# %%
df['total_cases'].min()
# Out:
# 0.0

# %% [markdown]
# # Describing 'total_deaths'

# %%
df['total_deaths'].describe().round(2)
# Out:
# count      57394.00
# mean        5302.02
# std        49128.02
# min            0.00
# 25%            1.00
# 50%           31.00
# 75%          354.00
# max      1328537.00
# Name: total_deaths, dtype: float64

# %% [markdown]
# # Update the dataframe with only this columns: ['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index']

# %%
df=df[['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index']]

# %%
df
# Out:
#       continent       location        date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  2019-12-31          0.0           0.0
# 1          Asia    Afghanistan  2020-01-01          0.0           0.0
# 2          Asia    Afghanistan  2020-02-01          0.0           0.0
# 3          Asia    Afghanistan  2020-03-01          0.0           0.0
# 4          Asia    Afghanistan  2020-04-01          0.0           0.0
# ...         ...            ...         ...          ...           ...
# 57389         0  International  2020-11-13        696.0           7.0
# 57390         0  International  2020-11-14        696.0           7.0
# 57391         0  International  2020-11-15        696.0           7.0
# 57392         0  International  2020-11-16        696.0           7.0
# 57393         0  International  2020-11-17        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# ...

# %% [markdown]
# # Find max value in 'continent' column

# %%
df.groupby('continent').max().reset_index()
# Out:
#        continent                      location        date  total_cases  \
# 0              0                         World  2020-12-11   55154651.0
# 1         Africa                      Zimbabwe  2020-12-11     752269.0
# 2           Asia                         Yemen  2020-12-11    8874290.0
# 3         Europe                       Vatican  2020-12-11    1991233.0
# 4  North America  United States Virgin Islands  2020-12-11   11205486.0
# 5        Oceania             Wallis and Futuna  2020-12-11      27750.0
# 6  South America                     Venezuela  2020-12-11    5876464.0
#
#    total_deaths  gdp_per_capita  human_development_index
# 0     1328537.0       15469.207                    0.000
# 1       20314.0       26382.287                    0.797
# 2      130519.0      116935.600                    0.933
# 3       52147.0       94277.965                    0.953
# 4      247220.0       54225.446                    0.926
# ...

# %% [markdown]
# # Store the result in a new dataframe named 'df_groupby'

# %%
df_groupby = df.groupby('continent').max().reset_index()
df_groupby
# Out:
#        continent                      location        date  total_cases  \
# 0              0                         World  2020-12-11   55154651.0
# 1         Africa                      Zimbabwe  2020-12-11     752269.0
# 2           Asia                         Yemen  2020-12-11    8874290.0
# 3         Europe                       Vatican  2020-12-11    1991233.0
# 4  North America  United States Virgin Islands  2020-12-11   11205486.0
# 5        Oceania             Wallis and Futuna  2020-12-11      27750.0
# 6  South America                     Venezuela  2020-12-11    5876464.0
#
#    total_deaths  gdp_per_capita  human_development_index
# 0     1328537.0       15469.207                    0.000
# 1       20314.0       26382.287                    0.797
# 2      130519.0      116935.600                    0.933
# 3       52147.0       94277.965                    0.953
# 4      247220.0       54225.446                    0.926
# ...

# %% [markdown]
# # Plot histogram for "gdp_per_capita"

# %%
sns.displot(df["gdp_per_capita"])

# %% [markdown]
# # Plot a scatter plot of 'total_cases' & 'gdp_per_capita'

# %%
sns.jointplot(data=df_groupby,x="total_cases",y="gdp_per_capita",kind="scatter")

# %% [markdown]
# # Plot Pairplot on df_groupby dataset.

# %%
sns.pairplot(data=df_groupby)

# %% [markdown]
# # Plot a bar plot of 'continent' column with 'total_cases'

# %%
sns.catplot(data=df_groupby,x="continent",y="total_cases",kind="bar")
